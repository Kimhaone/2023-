# %%
#2022년 행정구역별 고등학생의 4년제 대학진학률
import pandas as pd

df = pd.read_csv('행정구역별_2022.csv',encoding='cp949' )
df1 = df.query('학제 in ["고등학교", "(일반고)", "(특목고)", "(특성화고)", "(자율고)"]')

df2= df1.rename(columns = {df1.columns[5]:"졸업후진학자",
                               df1.columns[6]:"졸업후취업자",
                               df1.columns[7]:"졸업후입대자",
                               df1.columns[8]:"졸업후기타",
                               df1.columns[9]:"국내전문대학진학자",
                               df1.columns[10]:"국내대학진학자",
                               df1.columns[11]:"국외전문대학진학자",
                               df1.columns[12]:"국외대학진학자"})



#고등학교=일반고+특목고+특성화고+자율고

df2_univ = df2.query('학제 in ["고등학교"]')
df2_univ['졸업자'] = df2_univ['졸업자'].astype('float')
df2_univ['국내대학진학자'] = df2_univ['국내대학진학자'].astype('float')
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2557845572.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_univ['졸업자'] = df2_univ['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2557845572.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_univ['국내대학진학자'] = df2_univ['국내대학진학자'].astype('float')

# %%
df2_univ['국내4년제대학진학률'] = (df2_univ['국내대학진학자']/df2_univ['졸업자'])
df2_univ
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3901176700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_univ['국내4년제대학진학률'] = (df2_univ['국내대학진학자']/df2_univ['졸업자'])
#      시도  행정구역    학제   입학자     졸업자 졸업후진학자 졸업후취업자 졸업후입대자 졸업후기타 국내전문대학진학자  \
# 4    서울   종로구  고등학교  2505  2742.0   1638    162      7   935       330
# 15   서울    중구  고등학교  1770  2230.0   1043    396     95   696       364
# 25   서울   용산구  고등학교  1478  1794.0   1030    193     12   559       286
# 32   서울   성동구  고등학교  1251  1404.0    828    124      1   451       313
# 40   서울   광진구  고등학교  2485  2540.0   1628     22      3   887       337
# 49   서울  동대문구  고등학교  2055  2270.0   1519    158      1   592       417
# ...

# %%
df2_univ1 = df2_univ[['행정구역', '국내4년제대학진학률']]
df2_univ1.sort_values('국내4년제대학진학률', ascending = False)
# Out:
#      행정구역  국내4년제대학진학률
# 112  서대문구    0.568513
# 40    광진구    0.503937
# 49   동대문구    0.484581
# 157   금천구    0.476621
# 4     종로구    0.468636
# 224   강동구    0.453099
# 214   송파구    0.451837
# 203   강남구    0.448962
# 57    중랑구    0.440964
# 130   양천구    0.437470
# 193   서초구    0.433354
# 138   강서구    0.430364
# 82    도봉구    0.430088
# 166  영등포구    0.429864
# 92    노원구    0.428571
# 64    성북구    0.425316
# 183   관악구    0.419418
# 25    용산구    0.413601
# 147   구로구    0.412637
# 102   은평구    0.410677
# 73    강북구    0.410618
# 175   동작구    0.371082
# 32    성동구    0.365385
# 121   마포구    0.360488
# 15     중구    0.300897

# %%
#2022-일반고 대학진학률
df_univ_no = df2.query('학제 in ["(일반고)"]')
df_univ_no['졸업자'] = df_univ_no['졸업자'].astype('float')
df_univ_no['국내대학진학자'] = df_univ_no['국내대학진학자'].astype('float')
df_univ_no['일반고학생_국내4년제대학진학률'] = (df_univ_no['국내대학진학자']/df_univ_no['졸업자'])
df_univ_no1 = df_univ_no[['행정구역', '일반고학생_국내4년제대학진학률']]
df_univ_no1.sort_values('일반고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\4040976775.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_no['졸업자'] = df_univ_no['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\4040976775.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_no['국내대학진학자'] = df_univ_no['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\4040976775.py:5: SettingWithCopyWarning:
# ...

# %%
#2022-특목고 대학진학률
df_univ_sp = df2.query('학제 in ["(특목고)"]')
df_univ_sp['졸업자'] = df_univ_sp['졸업자'].astype('float')
df_univ_sp['국내대학진학자'] = df_univ_sp['국내대학진학자'].astype('float')
df_univ_sp['특목고학생_국내4년제대학진학률'] = (df_univ_sp['국내대학진학자']/df_univ_sp['졸업자'])
df_univ_sp1 = df_univ_sp[['행정구역', '특목고학생_국내4년제대학진학률']]
df_univ_sp1.sort_values('특목고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\4264912533.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sp['졸업자'] = df_univ_sp['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\4264912533.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sp['국내대학진학자'] = df_univ_sp['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\4264912533.py:5: SettingWithCopyWarning:
# ...

# %%
#2022-특성화고 대학진학률
df_univ_sd = df2.query('학제 in ["(특성화고)"]')
df_univ_sd['졸업자'] = df_univ_sd['졸업자'].astype('float')
df_univ_sd['국내대학진학자'] = df_univ_sd['국내대학진학자'].astype('float')
df_univ_sd['특성화고학생_국내4년제대학진학률'] = (df_univ_sd['국내대학진학자']/df_univ_sd['졸업자'])
df_univ_sd1 = df_univ_sd[['행정구역', '특성화고학생_국내4년제대학진학률']]
df_univ_sd1.sort_values('특성화고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3791034630.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sd['졸업자'] = df_univ_sd['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3791034630.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sd['국내대학진학자'] = df_univ_sd['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3791034630.py:5: SettingWithCopyWarning:
# ...

# %%
#2022-자율고 대학진학률
df_univ_ah = df2.query('학제 in ["(자율고)"]')
df_univ_ah['졸업자'] = df_univ_ah['졸업자'].astype('float')
df_univ_ah['국내대학진학자'] = df_univ_ah['국내대학진학자'].astype('float')
df_univ_ah['자율고학생_국내4년제대학진학률'] = (df_univ_ah['국내대학진학자']/df_univ_ah['졸업자'])
df_univ_ah1 = df_univ_ah[['행정구역', '자율고학생_국내4년제대학진학률']]
df_univ_ah1.sort_values('자율고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2475129840.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_ah['졸업자'] = df_univ_ah['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2475129840.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_ah['국내대학진학자'] = df_univ_ah['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2475129840.py:5: SettingWithCopyWarning:
# ...

# %%
#2021년 행정구역별 고등학생의 4년제 대학진학률
import pandas as pd

df11 = pd.read_csv('행정구역별2021.csv')
df12 = df11.query('학제 in ["고등학교", "(일반고)", "(특목고)", "(특성화고)", "(자율고)"]')

df13= df12.rename(columns = {df12.columns[5]:"졸업후진학자",
                             df12.columns[6]:"졸업후취업자",
                             df12.columns[7]:"졸업후입대자",
                             df12.columns[8]:"졸업후기타",
                             df12.columns[9]:"국내전문대학진학자",
                             df12.columns[10]:"국내대학진학자",
                             df12.columns[11]:"국외전문대학진학자",
                             df12.columns[12]:"국외대학진학자"})



#고등학교=일반고+특목고+특성화고+자율고

df13_univ = df13.query('학제 in ["고등학교"]')
df13_univ['졸업자'] = df13_univ['졸업자'].astype('float')
df13_univ['국내대학진학자'] = df13_univ['국내대학진학자'].astype('float')

df13_univ['국내4년제대학진학률'] = (df13_univ['국내대학진학자']/df13_univ['졸업자'])

df13_univ
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_24256\3177164605.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13_univ['졸업자'] = df13_univ['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_24256\3177164605.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13_univ['국내대학진학자'] = df13_univ['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_24256\3177164605.py:24: SettingWithCopyWarning:
# ...

# %%
df13_univ1 = df13_univ[['행정구역', '국내전문대학진학자']]
df13_univ1
# Out:
#      행정구역 국내전문대학진학자
# 4     종로구       363
# 15     중구       400
# 25    용산구       319
# 32    성동구       419
# 40    광진구       396
# 49   동대문구       404
# 57    중랑구       535
# 64    성북구       511
# 73    강북구       394
# 82    도봉구       446
# 92    노원구      1383
# 102   은평구       846
# 112  서대문구       253
# 121   마포구       393
# 131   양천구       728
# 139   강서구      1073
# 148   구로구       811
# 158   금천구       282
# 167  영등포구       420
# 176   동작구       377
# 184   관악구       549
# 194   서초구       279
# 204   강남구       486
# 215   송파구       927
# 225   강동구       635

# %%
#2021-일반고 대학진학률
df_univ_no11 = df13.query('학제 in ["(일반고)"]')
df_univ_no11['졸업자'] = df_univ_no11['졸업자'].astype('float')
df_univ_no11['국내대학진학자'] = df_univ_no11['국내대학진학자'].astype('float')
df_univ_no11['일반고학생_국내4년제대학진학률'] = (df_univ_no11['국내대학진학자']/df_univ_no11['졸업자'])
df_univ_no12 = df_univ_no11[['행정구역', '일반고학생_국내4년제대학진학률']]
df_univ_no12.sort_values('일반고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2920509547.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_no11['졸업자'] = df_univ_no11['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2920509547.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_no11['국내대학진학자'] = df_univ_no11['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2920509547.py:5: SettingWithCopyWarning:
# ...

# %%
#2021-특목고대학진학률
df_univ_sp11 = df13.query('학제 in ["(특목고)"]')
df_univ_sp11['졸업자'] = df_univ_sp11['졸업자'].astype('float')
df_univ_sp11['국내대학진학자'] = df_univ_sp11['국내대학진학자'].astype('float')
df_univ_sp11['특목고학생_국내4년제대학진학률'] = (df_univ_sp11['국내대학진학자']/df_univ_sp11['졸업자'])
df_univ_sp12 = df_univ_sp11[['행정구역', '특목고학생_국내4년제대학진학률']]
df_univ_sp12.sort_values('특목고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2520116744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sp11['졸업자'] = df_univ_sp11['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2520116744.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sp11['국내대학진학자'] = df_univ_sp11['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2520116744.py:5: SettingWithCopyWarning:
# ...

# %%
#2021-특성화고 대학진학률
df_univ_sd11 = df13.query('학제 in ["(특성화고)"]')
df_univ_sd11['졸업자'] = df_univ_sd11['졸업자'].astype('float')
df_univ_sd11['국내대학진학자'] = df_univ_sd11['국내대학진학자'].astype('float')
df_univ_sd11['특성화고학생_국내4년제대학진학률'] = (df_univ_sd11['국내대학진학자']/df_univ_sd11['졸업자'])
df_univ_sd12 = df_univ_sd11[['행정구역', '특성화고학생_국내4년제대학진학률']]
df_univ_sd12.sort_values('특성화고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\1856830119.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sd11['졸업자'] = df_univ_sd11['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\1856830119.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sd11['국내대학진학자'] = df_univ_sd11['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\1856830119.py:5: SettingWithCopyWarning:
# ...

# %%
#2021-자율고 대학진학률
df_univ_ah11 = df13.query('학제 in ["(자율고)"]')
df_univ_ah11['졸업자'] = df_univ_ah11['졸업자'].astype('float')
df_univ_ah11['국내대학진학자'] = df_univ_ah11['국내대학진학자'].astype('float')
df_univ_ah11['자율고학생_국내4년제대학진학률'] = (df_univ_ah11['국내대학진학자']/df_univ_ah11['졸업자'])
df_univ_ah12 = df_univ_ah11[['행정구역', '자율고학생_국내4년제대학진학률']]
df_univ_ah12.sort_values('자율고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3262790791.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_ah11['졸업자'] = df_univ_ah11['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3262790791.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_ah11['국내대학진학자'] = df_univ_ah11['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3262790791.py:5: SettingWithCopyWarning:
# ...

# %%
#2020년 행정구역별 고등학생의 4년제 대학진학률
import pandas as pd

df21 = pd.read_csv('행정구역별2020.csv')
df22 = df21.query('학제 in ["고등학교", "(일반고)", "(특목고)", "(특성화고)", "(자율고)"]')

df23= df22.rename(columns = {df22.columns[5]:"졸업후진학자",
                             df22.columns[6]:"졸업후취업자",
                             df22.columns[7]:"졸업후입대자",
                             df22.columns[8]:"졸업후기타",
                             df22.columns[9]:"국내전문대학진학자",
                             df22.columns[10]:"국내교육대학진학자",
                             df22.columns[11]:"국내대학진학자",
                             df22.columns[12]:"국내각종학교진학자",
                             df22.columns[13]:"국외전문대학진학자",
                             df22.columns[14]:"국외대학진학자"})


df23_univ = df23.query('학제 in ["고등학교"]')
df23_univ['졸업자'] = df23_univ['졸업자'].astype('float')
df23_univ['국내대학진학자'] = df23_univ['국내대학진학자'].astype('float')

df23_univ['국내4년제대학진학률'] = (df23_univ['국내대학진학자']/df23_univ['졸업자'])

df23_univ


#고등학교=일반고+특목고+특성화고+자율고
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3303903214.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df23_univ['졸업자'] = df23_univ['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3303903214.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df23_univ['국내대학진학자'] = df23_univ['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3303903214.py:23: SettingWithCopyWarning:
# ...

# %%
df23_univ1 = df23_univ[['행정구역', '국내4년제대학진학률']]
df23_univ1.sort_values('국내4년제대학진학률', ascending = False)
# Out:
#      행정구역  국내4년제대학진학률
# 117  서대문구    0.468258
# 41    광진구    0.462736
# 51   동대문구    0.460426
# 234   강동구    0.435996
# 4     종로구    0.423423
# 213   강남구    0.419884
# 67    성북구    0.408943
# 136   양천구    0.403121
# 224   송파구    0.401316
# 165   금천구    0.393266
# 175  영등포구    0.386814
# 203   서초구    0.383477
# 107   은평구    0.381215
# 144   강서구    0.378690
# 96    노원구    0.377957
# 59    중랑구    0.373803
# 86    도봉구    0.371429
# 192   관악구    0.369501
# 77    강북구    0.354102
# 126   마포구    0.353436
# 184   동작구    0.345921
# 25    용산구    0.343387
# 33    성동구    0.334512
# 154   구로구    0.328723
# 15     중구    0.297899

# %%
#2020-일반고 대학진학률
df_univ_no21 = df23.query('학제 in ["(일반고)"]')
df_univ_no21['졸업자'] = df_univ_no21['졸업자'].astype('float')
df_univ_no21['국내대학진학자'] = df_univ_no21['국내대학진학자'].astype('float')
df_univ_no21['일반고학생_국내4년제대학진학률'] = (df_univ_no21['국내대학진학자']/df_univ_no21['졸업자'])
df_univ_no22 = df_univ_no21[['행정구역', '일반고학생_국내4년제대학진학률']]
df_univ_no22.sort_values('일반고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\524289134.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_no21['졸업자'] = df_univ_no21['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\524289134.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_no21['국내대학진학자'] = df_univ_no21['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\524289134.py:5: SettingWithCopyWarning:
# ...

# %%
#2020-특목고 대학진학률
df_univ_sp21 = df23.query('학제 in ["(특목고)"]')
df_univ_sp21['졸업자'] = df_univ_sp21['졸업자'].astype('float')
df_univ_sp21['국내대학진학자'] = df_univ_sp21['국내대학진학자'].astype('float')
df_univ_sp21['특목고학생_국내4년제대학진학률'] = (df_univ_sp21['국내대학진학자']/df_univ_sp21['졸업자'])
df_univ_sp22 = df_univ_sp21[['행정구역', '특목고학생_국내4년제대학진학률']]
df_univ_sp22.sort_values('특목고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3617561915.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sp21['졸업자'] = df_univ_sp21['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3617561915.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sp21['국내대학진학자'] = df_univ_sp21['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3617561915.py:5: SettingWithCopyWarning:
# ...

# %%
#2020-특성화고 대학진학률
df_univ_sd21 = df23.query('학제 in ["(특성화고)"]')
df_univ_sd21['졸업자'] = df_univ_sd21['졸업자'].astype('float')
df_univ_sd21['국내대학진학자'] = df_univ_sd21['국내대학진학자'].astype('float')
df_univ_sd21['특성화고학생_국내4년제대학진학률'] = (df_univ_sd21['국내대학진학자']/df_univ_sd21['졸업자'])
df_univ_sd22 = df_univ_sd21[['행정구역', '특성화고학생_국내4년제대학진학률']]
df_univ_sd22.sort_values('특성화고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\4262064374.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sd21['졸업자'] = df_univ_sd21['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\4262064374.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sd21['국내대학진학자'] = df_univ_sd21['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\4262064374.py:5: SettingWithCopyWarning:
# ...

# %%
#2020-자율고 대학진학률
df_univ_ah21 = df23.query('학제 in ["(자율고)"]')
df_univ_ah21['졸업자'] = df_univ_ah21['졸업자'].astype('float')
df_univ_ah21['국내대학진학자'] = df_univ_ah21['국내대학진학자'].astype('float')
df_univ_ah21['자율고학생_국내4년제대학진학률'] = (df_univ_ah21['국내대학진학자']/df_univ_ah21['졸업자'])
df_univ_ah22 = df_univ_ah21[['행정구역', '자율고학생_국내4년제대학진학률']]
df_univ_ah22.sort_values('자율고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3950600042.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_ah21['졸업자'] = df_univ_ah21['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3950600042.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_ah21['국내대학진학자'] = df_univ_ah21['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3950600042.py:5: SettingWithCopyWarning:
# ...

# %%
#2019년 행정구역별 고등학생의 4년제 대학진학률
import pandas as pd

df31 = pd.read_csv('행정구역별2019.csv')
df32 = df31.query('학제 in ["고등학교", "(일반고)", "(특목고)", "(특성화고)", "(자율고)"]')

df33= df32.rename(columns = {df32.columns[5]:"졸업후진학자",
                             df32.columns[6]:"졸업후취업자",
                             df32.columns[7]:"졸업후입대자",
                             df32.columns[8]:"졸업후기타",
                             df32.columns[9]:"국내전문대학진학자",
                             df32.columns[10]:"국내교육대학진학자",
                             df32.columns[11]:"국내대학진학자",
                             df32.columns[12]:"국내각종학교진학자",
                             df32.columns[13]:"국외전문대학진학자",
                             df32.columns[14]:"국외대학진학자"})


df33_univ = df33.query('학제 in ["고등학교"]')
df33_univ['졸업자'] = df33_univ['졸업자'].astype('float')
df33_univ['국내대학진학자'] = df33_univ['국내대학진학자'].astype('float')

df33_univ['국내4년제대학진학률'] = (df33_univ['국내대학진학자']/df33_univ['졸업자'])


df33_univ
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2092521647.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df33_univ['졸업자'] = df33_univ['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2092521647.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df33_univ['국내대학진학자'] = df33_univ['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\2092521647.py:23: SettingWithCopyWarning:
# ...

# %%
df33_univ1 = df33_univ[['행정구역', '국내4년제대학진학률']]
df33_univ1.sort_values('국내4년제대학진학률', ascending = False)
# Out:
#      행정구역  국내4년제대학진학률
# 41    광진구    0.433742
# 204   서초구    0.429376
# 117  서대문구    0.416433
# 235   강동구    0.396991
# 225   송파구    0.386241
# 165   금천구    0.385284
# 4     종로구    0.383730
# 67    성북구    0.380242
# 136   양천구    0.375827
# 214   강남구    0.371021
# 86    도봉구    0.369174
# 51   동대문구    0.362877
# 175  영등포구    0.358409
# 96    노원구    0.356506
# 107   은평구    0.349509
# 59    중랑구    0.348862
# 25    용산구    0.343699
# 144   강서구    0.333014
# 193   관악구    0.330488
# 77    강북구    0.327727
# 126   마포구    0.320652
# 154   구로구    0.316597
# 184   동작구    0.297949
# 33    성동구    0.284604
# 15     중구    0.265268

# %%
#2019-일반고 대학진학률
df_univ_no31 = df33.query('학제 in ["(일반고)"]')
df_univ_no31['졸업자'] = df_univ_no31['졸업자'].astype('float')
df_univ_no31['국내대학진학자'] = df_univ_no31['국내대학진학자'].astype('float')
df_univ_no31['일반고학생_국내4년제대학진학률'] = (df_univ_no31['국내대학진학자']/df_univ_no31['졸업자'])
df_univ_no32 = df_univ_no31[['행정구역', '일반고학생_국내4년제대학진학률']]
df_univ_no32.sort_values('일반고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3507819132.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_no31['졸업자'] = df_univ_no31['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3507819132.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_no31['국내대학진학자'] = df_univ_no31['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\3507819132.py:5: SettingWithCopyWarning:
# ...

# %%
#2019-특목고 대학진학률
df_univ_sp31 = df33.query('학제 in ["(특목고)"]')
df_univ_sp31['졸업자'] = df_univ_sp31['졸업자'].astype('float')
df_univ_sp31['국내대학진학자'] = df_univ_sp31['국내대학진학자'].astype('float')
df_univ_sp31['특목고학생_국내4년제대학진학률'] = (df_univ_sp31['국내대학진학자']/df_univ_sp31['졸업자'])
df_univ_sp32 = df_univ_sp31[['행정구역', '특목고학생_국내4년제대학진학률']]
df_univ_sp32.sort_values('특목고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\1034342584.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sp31['졸업자'] = df_univ_sp31['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\1034342584.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sp31['국내대학진학자'] = df_univ_sp31['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\1034342584.py:5: SettingWithCopyWarning:
# ...

# %%
#2019-특성화고 대학진학률
df_univ_sd31 = df33.query('학제 in ["(특성화고)"]')
df_univ_sd31['졸업자'] = df_univ_sd31['졸업자'].astype('float')
df_univ_sd31['국내대학진학자'] = df_univ_sd31['국내대학진학자'].astype('float')
df_univ_sd31['특성화고학생_국내4년제대학진학률'] = (df_univ_sd31['국내대학진학자']/df_univ_sd31['졸업자'])
df_univ_sd32 = df_univ_sd31[['행정구역', '특성화고학생_국내4년제대학진학률']]
df_univ_sd32.sort_values('특성화고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\519232930.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sd31['졸업자'] = df_univ_sd31['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\519232930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_sd31['국내대학진학자'] = df_univ_sd31['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\519232930.py:5: SettingWithCopyWarning:
# ...

# %%
#2019-자율고 대학진학률
df_univ_ah31 = df33.query('학제 in ["(자율고)"]')
df_univ_ah31['졸업자'] = df_univ_ah31['졸업자'].astype('float')
df_univ_ah31['국내대학진학자'] = df_univ_ah31['국내대학진학자'].astype('float')
df_univ_ah31['자율고학생_국내4년제대학진학률'] = (df_univ_ah31['국내대학진학자']/df_univ_ah31['졸업자'])
df_univ_ah32 = df_univ_ah31[['행정구역', '자율고학생_국내4년제대학진학률']]
df_univ_ah32.sort_values('자율고학생_국내4년제대학진학률', ascending = False)
# Out:
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\1481170770.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_ah31['졸업자'] = df_univ_ah31['졸업자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\1481170770.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_univ_ah31['국내대학진학자'] = df_univ_ah31['국내대학진학자'].astype('float')
# C:\Users\onlyo\AppData\Local\Temp\ipykernel_14532\1481170770.py:5: SettingWithCopyWarning:
# ...
